# %%
import pandas as pd
import numpy as np
datafile = "311_Service_Requests_2020.csv"
df = pd.read_csv(datafile)
df
# Out:
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (20,31,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#          Unique Key            Created Date             Closed Date Agency  \
# 0          45285347  01/01/2020 12:00:00 AM  01/10/2020 12:00:01 AM  DOHMH
# 1          45285651  01/01/2020 12:00:00 AM  01/02/2020 12:00:01 AM  DOHMH
# 2          45285821  01/01/2020 12:00:00 AM  01/02/2020 09:50:09 AM  DOHMH
# 3          45287907  01/01/2020 12:00:00 AM  01/02/2020 12:00:01 AM  DOHMH
# 4          45288240  01/01/2020 12:00:00 AM  01/02/2020 12:00:01 AM  DOHMH
# ...             ...                     ...                     ...    ...
# 2587311    48536847  12/31/2020 12:00:00 AM  12/31/2020 02:10:48 PM  DOHMH
# 2587312    48537845  12/31/2020 12:00:00 AM  12/31/2020 02:10:13 PM  DOHMH
# ...

# %%
df = df[df['Incident Zip']==10023]
df
# Out:
#          Unique Key            Created Date             Closed Date Agency  \
# 809        45286081  01/01/2020 02:48:36 AM  02/26/2020 09:28:47 AM    TLC
# 1068       45286436  01/01/2020 03:58:29 AM  01/01/2020 04:59:47 AM   NYPD
# 1718       45289660  01/01/2020 09:41:00 AM  01/17/2020 12:00:00 PM   DSNY
# 2197       45293063  01/01/2020 12:07:52 PM  01/06/2020 09:30:00 AM    DOT
# 2602       45289175  01/01/2020 01:57:41 PM  01/01/2020 04:26:21 PM    DHS
# ...             ...                     ...                     ...    ...
# 2585904    48530701  12/30/2020 06:49:27 PM  12/30/2020 06:58:30 PM   NYPD
# 2586136    48533213  12/30/2020 07:46:00 PM  01/05/2021 08:19:00 AM    DOT
# 2586350    48534338  12/30/2020 08:33:55 PM  12/30/2020 08:39:10 PM   NYPD
# 2586921    48541280  12/30/2020 10:39:00 PM  01/05/2021 12:00:00 PM   DSNY
# 2587315    48543111  12/31/2020 12:00:00 AM  12/31/2020 12:00:01 AM  DOHMH
#
# ...

# %%
call_type = df.groupby(df['Complaint Type']).size()
call_type
# Out:
# Complaint Type
# APPLIANCE                   23
# Abandoned Vehicle           24
# Air Quality                 96
# Animal in a Park             6
# Animal-Abuse                58
#                           ...
# Violation of Park Rules     30
# WATER LEAK                  41
# Water Conservation           5
# Water Quality               36
# Water System               171
# Length: 124, dtype: int64
